# %% [markdown]
# # 🛰️ Afet-Rota-AI: Rota Optimizasyon Simulasyonu
#
# Bu notebook, uydu görüntüleri ve yol ağı verilerini kullanarak otonom rota optimizasyonunu simüle eder.

# %%
import os
import sys
sys.path.append('..')

from src.routing.main_navigator import calculate_route
from src.vision.damage_assessment import DamageScanner

# %% [markdown]
# ## 1. Senaryo Hazırlığı
# İstanbul Havalimanı bölgesinde bir afet senaryosu simüle edilmektedir.

# %%
start_coord = "41.015,28.979"
target_coord = "41.025,28.985"

print(f"[*] Simülasyon Başlatılıyor: {start_coord} -> {target_coord}")
route = calculate_route(start_coord, target_coord, disaster_data=True)
print("[+] Rota Hesaplandı.")
